# %% [markdown]
# # Bulk solution energy: Al in bcc Fe
#
# Builds a Fe supercell with one Al substitutional, then computes
# `E_supercell+1Al - E_supercell` (= the bare solution energy
# ignoring chemical-potential references). All work runs through the
# Engine API; sub-folders are derived via `engine.with_working_directory(...)`.

# %%
import flowrep as fr
import pathlib
import pyiron_workflow as pwf
from ase.build import bulk
from ase.calculators.eam import EAM

from pyiron_workflow_atomistics.engine import ASEEngine, CalcInputMinimize, calculate, subengine
from pyiron_workflow_atomistics.physics.bulk import optimise_cubic_lattice_parameter
from pyiron_workflow_atomistics.structure import (
    create_supercell_with_min_dimensions,
    substitutional_swap,
)

engine = ASEEngine(
    EngineInput=CalcInputMinimize(
        force_convergence_tolerance=0.05, max_iterations=100
    ),
    calculator=EAM(potential=str(next(p for p in [pathlib.Path("Al-Fe.eam.fs"), pathlib.Path("notebooks/Al-Fe.eam.fs"), pathlib.Path(__file__).parent / "Al-Fe.eam.fs" if "__file__" in globals() else pathlib.Path(".")] if p.exists()))),
    working_directory="./_sol_runs",
)

# %%
@fr.atomic("solution_energy")
def calculate_soln_energy(bulk_energy, sol_energy):
    return sol_energy - bulk_energy

# %%
wf = pwf.Workflow("bulk_solution_energy")
wf.create_input(
    "engine",
    "structure",
    "host_symbol", # Dangerous: must be synchronized to structure
    "crystal_structure", # Dangerous: must be synchronized to structure
    "strain_range",
    "num_points",
    "min_dimensions",
    "solute_symbol",
    "defect_site_index",
)

wf.lat_opt_engine = pwf.node(
    subengine,
    engine=wf.inputs.engine,
    subdir="lat_opt",
)
wf.lat_opt = pwf.node(
    optimise_cubic_lattice_parameter,
    structure=wf.inputs.structure,
    name=wf.inputs.host_symbol,
    crystalstructure=wf.inputs.crystal_structure,
    engine=wf.lat_opt_engine,
    strain_range=wf.inputs.strain_range,
    num_points=wf.inputs.num_points,
)

wf.supercell = pwf.node(
    create_supercell_with_min_dimensions,
    base_structure=wf.lat_opt.outputs.equil_struct,
    min_dimensions=wf.inputs.min_dimensions,
)
wf.supercell_with_1sol = pwf.node(
    substitutional_swap,
    base_structure=wf.supercell,
    defect_site=wf.inputs.defect_site_index,
    new_symbol=wf.inputs.solute_symbol,
)

wf.calc_bulk_engine = pwf.node(
    subengine,
    engine=wf.inputs.engine,
    subdir="bulk",
)
wf.calc_bulk = pwf.node(
    calculate,
    structure=wf.supercell,
    engine=wf.calc_bulk_engine,
)
wf.calc_sol_engine = pwf.node(
    subengine,
    engine=wf.inputs.engine,
    subdir="sol",
)
wf.calc_sol = pwf.node(
    calculate,
    structure=wf.supercell_with_1sol,
    engine=wf.calc_sol_engine,
)

wf.bulk_energy = pwf.node(
    fr.std.get_attr,
    obj=wf.calc_bulk.outputs.engine_output,
    name="final_energy",
)
wf.sol_energy = pwf.node(
    fr.std.get_attr,
    obj=wf.calc_sol.outputs.engine_output,
    name="final_energy"
)

wf.soln_energy = pwf.node(calculate_soln_energy)(
    bulk_energy=wf.bulk_energy,
    sol_energy=wf.sol_energy,
)

wf.create_output_from(wf.lat_opt.outputs.a0)
wf.create_output_from(wf.lat_opt.outputs.B)
wf.create_output_from(wf.supercell)
wf.create_output_from(wf.bulk_energy, "bulk_energy")
wf.create_output_from(wf.sol_energy, "sol_energy")
wf.create_output_from(wf.soln_energy)
# Out:
# [AddOutput(port=OutputPort(label='solution_energy', owner=<pyiron_workflow.workflow_node.Workflow object at 0x1612d1280>, type_hint=None, type_metadata=None)),
#  AddEdge(edge=EdgeTuple(source=SourceHandle(node='soln_energy', port='solution_energy'), target=OutputTarget(node=None, port='solution_energy')))]

# %%
run = wf.run(
    engine=engine,
    structure=bulk("Fe", a=2.85, cubic=True),
    host_symbol="Fe",
    crystal_structure="bcc",
    strain_range=(-0.02, 0.02),
    num_points=5,
    min_dimensions=[7, 7, 7],
    solute_symbol="Al",
    defect_site_index=0,
)
# Out:
#       Step     Time          Energy          fmax
# BFGS:    0 20:39:42       -7.968559        0.000000
#       Step     Time          Energy          fmax
# BFGS:    0 20:39:42       -8.009283        0.000000
#       Step     Time          Energy          fmax
# BFGS:    0 20:39:42       -8.025561        0.000000
#       Step     Time          Energy          fmax
# BFGS:    0 20:39:42       -8.018422        0.000000
#       Step     Time          Energy          fmax
# BFGS:    0 20:39:42       -7.989335        0.000000
#       Step     Time          Energy          fmax
# BFGS:    0 20:39:42     -216.701043        0.000000
#       Step     Time          Energy          fmax
# BFGS:    0 20:39:42     -217.043811        0.179410
# BFGS:    1 20:39:42     -217.047838        0.160072
# BFGS:    2 20:39:42     -217.065588        0.056327
# BFGS:    3 20:39:42     -217.066334        0.046761

# %%
out = run.outputs
print(f"Optimised lattice parameter: a0 = {run.outputs.a0:.4f} A  (B = {run.outputs.B:.1f} GPa)")

n_atoms = len(run.outputs.supercell)
print(f"Solution energy of Al in Fe BCC (Al-Fe.eam.fs): "
      f"{run.outputs.solution_energy:.3f} eV")
print(f"E_bulk ({n_atoms} Fe) = {run.outputs.bulk_energy:.3f} eV")
print(f"E_sol  ({n_atoms - 1} Fe + 1 Al) = {run.outputs.sol_energy:.3f} eV")
# Out:
# Optimised lattice parameter: a0 = 2.8554 A  (B = 176.9 GPa)
# Solution energy of Al in Fe BCC (Al-Fe.eam.fs): -0.365 eV
# E_bulk (54 Fe) = -216.701 eV
# E_sol  (53 Fe + 1 Al) = -217.066 eV
