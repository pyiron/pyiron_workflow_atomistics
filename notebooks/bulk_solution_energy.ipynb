# %% [markdown]
# # Bulk solution energy: Al in bcc Fe
#
# Builds a Fe supercell with one Al substitutional, then computes
# `E_supercell+1Al - E_supercell` (= the bare solution energy
# ignoring chemical-potential references). All work runs through the
# Engine API; sub-folders are derived via `engine.with_working_directory(...)`.

# %%
import pyiron_workflow as pwf
from ase.build import bulk
from ase.calculators.eam import EAM

from pyiron_workflow_atomistics.engine import ASEEngine, CalcInputMinimize, run
from pyiron_workflow_atomistics.structure import (
    create_supercell_with_min_dimensions,
    substitutional_swap,
)

engine = ASEEngine(
    EngineInput=CalcInputMinimize(
        force_convergence_tolerance=0.05, max_iterations=100
    ),
    calculator=EAM(potential="Al-Fe.eam.fs"),
    working_directory="./_sol_runs",
)

# %%
from pyiron_workflow import Workflow

@pwf.as_function_node("solution_energy")
def calculate_soln_energy(bulk_energy, sol_energy):
    return sol_energy - bulk_energy

fe_bulk = bulk("Fe", a=2.85, cubic=True)

wf = Workflow("bulk_solution_energy")
wf.supercell = create_supercell_with_min_dimensions(
    fe_bulk, min_dimensions=[7, 7, 7]
)
wf.supercell_with_1sol = substitutional_swap(
    wf.supercell, defect_site=0, new_symbol="Al"
)
wf.calc_bulk = run(
    wf.supercell,
    engine=engine.with_working_directory("bulk"),
    label="calc_bulk",
)
wf.calc_sol = run(
    wf.supercell_with_1sol,
    engine=engine.with_working_directory("sol"),
    label="calc_sol",
)
wf.soln_energy = calculate_soln_energy(
    bulk_energy=wf.calc_bulk.outputs.engine_output.final_energy,
    sol_energy=wf.calc_sol.outputs.engine_output.final_energy,
)
wf.run()

n_atoms = len(wf.supercell.value)
print(f"Solution energy of Al in Fe BCC (Al-Fe.eam.fs): "
      f"{wf.soln_energy.outputs.solution_energy.value:.3f} eV")
print(f"E_bulk ({n_atoms} Fe) = {wf.calc_bulk.outputs.engine_output.value.final_energy:.3f} eV")
print(f"E_sol  ({n_atoms - 1} Fe + 1 Al) = {wf.calc_sol.outputs.engine_output.value.final_energy:.3f} eV")
# Out:
#       Step     Time          Energy          fmax
# BFGS:    0 14:52:07     -216.690138        0.000000
#       Step     Time          Energy          fmax
# BFGS:    0 14:52:08     -217.042024        0.185068
# BFGS:    1 14:52:08     -217.046282        0.164879
# BFGS:    2 14:52:09     -217.064899        0.058957
# BFGS:    3 14:52:10     -217.065708        0.048944
# Solution energy of Al in Fe BCC (Al-Fe.eam.fs): -0.376 eV
# E_bulk (54 Fe) = -216.690 eV
# E_sol  (53 Fe + 1 Al) = -217.066 eV
